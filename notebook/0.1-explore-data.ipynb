# %% [markdown]
# # Imports

# %%
# install additional packages if running on Emscripten
import platform

notebook_platform = platform.uname()
if notebook_platform.system == "Emscripten":
    import piplite

    await piplite.install(["openpyxl", "seaborn"])

# %%
from enum import Enum
import pathlib
import pandas as pd
import seaborn as sns

sns.set_style("ticks", {"axes.grid": True})

# %% [markdown]
# # Data

# %%
this_file = pathlib.Path().absolute()
data_dir = this_file.parent / "data"
data_dir
# Out:
# WindowsPath('c:/Users/Legion/workspace/tld_let_calibration/data')

# %%
df_mcp = pd.read_excel(data_dir / "interim" / "Wyniki_DK_IFJ.xlsx", sheet_name="ifj_calib_mcp")
df_mcp
# Out:
#    Co_60_1Gy    MaxX   GlobalMax   From     To  LocalMaxX   LocalMaxY  \
# 0         NaN    NaN         NaN    NaN    NaN        NaN         NaN
# 1   70_80.dat  220.0  42508362.0  100.0  240.0      220.0  42508362.0
# 2   69_79.dat  220.0  38203506.0  100.0  240.0      220.0  38203506.0
# 3   68_78.dat  220.0  41660407.0  100.0  240.0      220.0  41660407.0
# 4   67_77.dat  220.0  42709273.0  100.0  240.0      220.0  42709273.0
# ..        ...    ...         ...    ...    ...        ...         ...
# 78    4_8.dat  220.0  43990872.0  100.0  240.0      220.0  43990872.0
# 79    3_7.dat  220.0  43491464.0  100.0  240.0      220.0  43491464.0
# 80    2_6.dat  220.0  41209867.0  100.0  240.0      220.0  41209867.0
# 81    1_5.dat  220.0  44775354.0  100.0  240.0      220.0  44775354.0
# 82        NaN    NaN         NaN    NaN    NaN        NaN         NaN
#
#         Integral           Sum       Eff  ...    Protony  MaxX.1 GlobalMax.1  \
# 0            NaN           NaN       NaN  ...        NaN     NaN         NaN
# 1   1.256320e+09  1.361056e+10  0.449283  ...  70_79.dat   220.0  18427955.0
# 2   1.138491e+09  1.238505e+10  0.461032  ...  69_78.dat   220.0  16996202.0
# 3   1.241656e+09  1.352417e+10  0.454406  ...  68_77.dat   220.0  18104315.0
# 4   1.257025e+09  1.368800e+10  0.449788  ...  67_76.dat   220.0  18265912.0
# ..           ...           ...       ...  ...        ...     ...         ...
# 78  1.288080e+09  1.401263e+10  0.842029  ...    4_7.dat   220.0  37945265.0
# 79  1.290799e+09  1.398400e+10  0.843554  ...    3_6.dat   220.0  37603310.0
# 80  1.236975e+09  1.345762e+10  0.838465  ...    2_5.dat   220.0  35211108.0
# 81  1.307468e+09  1.421510e+10  0.828864  ...    1_4.dat   220.0  37337157.0
# 82           NaN           NaN  0.841646  ...        NaN     NaN         NaN
#
#     From.1   To.1  LocalMaxX.1  LocalMaxY.1    Integral.1         Sum.1  \
# 0      NaN    NaN          NaN          NaN           NaN           NaN
# 1    100.0  240.0        220.0   18427955.0  5.644434e+08  6.135930e+08
# 2    100.0  240.0        220.0   16996202.0  5.248804e+08  5.714387e+08
# 3    100.0  240.0        220.0   18104315.0  5.642166e+08  6.101429e+08
# 4    100.0  240.0        220.0   18265912.0  5.653947e+08  6.114317e+08
# ..     ...    ...          ...          ...           ...           ...
# 78   100.0  240.0        220.0   37945265.0  1.084600e+09  1.183949e+10
# 79   100.0  240.0        220.0   37603310.0  1.088858e+09  1.187952e+10
# 80   100.0  240.0        220.0   35211108.0  1.037160e+09  1.124945e+10
# 81   100.0  240.0        220.0   37337157.0  1.083712e+09  1.182987e+10
# 82     NaN    NaN          NaN          NaN           NaN           NaN
#
#     dawka [Gy]
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# ..         ...
# 78         NaN
# 79         NaN
# 80         NaN
# 81         NaN
# 82         1.0
#
# [83 rows x 22 columns]

# %%
df_mcp.plot(y=["Integral", "Integral.1"])
# Out:
# <Axes: >

# %%
df_mcp.plot(y=["Eff"], grid=True)
# Out:
# <Axes: >
